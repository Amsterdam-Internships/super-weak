# %%
import spacy
from spacy.tokens import DocBin
path = "ned.spacy"
nlp = spacy.load("nl_core_news_md")

# %%
docbin = DocBin().from_disk(path)

# %%
docs = list(docbin.get_docs(nlp.vocab))

# %%
def relabel(ent_list: list):
    """
    returns a relabeled list of tuples (text, label) with new labels complying with ConLL labels 
    """
    mappings = {"PERSON":"PER", "COMPANY":"ORG", "GPE":"LOC", 'EVENT':"MISC", 'FAC':"MISC", 'LANGUAGE':"MISC", 
                      'LAW':"MISC", 'NORP':"MISC", 'PRODUCT':"MISC",'WORK_OF_ART':"MISC", "MISC":"MISC", "PER":"PER", "ORG":"ORG", "LOC":"LOC"}
    
    exclude = {"CARDINAL", "ORDINAL", "DATE", "PERCENT", "QUANTITY", "TIME", "MONEY"}
    return [(ent[0], mappings[ent[1]]) for ent in ent_list if ent[1] not in exclude]

def ent_tup(ent):
    """
    returns a tuple containing (text, label, start, end) for specified ent
    """
    return (ent.text, ent.label_)

def ent_list(doc):
    """
    returns list of tuples (text, label) of all entities in doc
    """
    ent_list = [ent_tup(ent) for ent in doc.ents]
    return relabel(ent_list)

def score(docs: list, truth: list):
    """
    returns scores (precision, recall, f1) of docs using truth as ground truth. 
    """
    tp = []
    fp = []
    fn = []
    
    for i, doc in enumerate(docs):
        pred = ent_list(doc)
        true = ent_list(truth[i])
        for ent in pred:
            pred_label = ent[1]
            pred_text = ent[0]
            for true_ent in true: 
                text = true_ent[0]
                label = true_ent[1]
                if pred_text in text or text in pred_text:
                    if pred_label == label:        
                        tp.append(ent)
                        break
                    else:
                        fp.append(ent)
                        break

        doc_fn = [ent for ent in true if ent not in tp + fp]
        fn.extend(doc_fn)
    
    precision = len(tp) / (len(tp) + len(fp))
    recall = len(tp) / (len(tp) + len(fn))
    f1 = 2 * (recall * precision) / (recall + precision)
    return {"precision" : precision, "recall" : recall, "f1" : f1}

testdocs = docs
otherdocs = [nlp(doc.text) for doc in testdocs]
score(testdocs, otherdocs)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-116-b8ad7b95ca85> in <module>
#      56
#      57 testdocs = docs
# ---> 58 otherdocs = [nlp(doc.text) for doc in testdocs]
#      59 score(testdocs, otherdocs)
#
# <ipython-input-116-b8ad7b95ca85> in <listcomp>(.0)
#      56
#      57 testdocs = docs
# ---> 58 otherdocs = [nlp(doc.text) for doc in testdocs]
#      59 score(testdocs, otherdocs)
#
# ~/.local/lib/python3.9/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     993                 error_handler = proc.get_error_handler()
#     994             try:
# --> 995                 doc = proc(doc, **component_cfg.get(name, {}))
#     996             except KeyError as e:
#     997                 # This typically happens if a component is not initialized
#
# ~/.local/lib/python3.9/site-packages/spacy/pipeline/trainable_pipe.pyx in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# ~/.local/lib/python3.9/site-packages/spacy/pipeline/tok2vec.py in predict(self, docs)
#     119         DOCS: https://spacy.io/api/tok2vec#predict
#     120         """
# --> 121         tokvecs = self.model.predict(docs)
#     122         batch_id = Tok2VecListener.get_batch_id(docs)
#     123         for listener in self.listeners:
#
# ~/.local/lib/python3.9/site-packages/thinc/model.py in predict(self, X)
#     310         only the output, instead of the `(output, callback)` tuple.
#     311         """
# --> 312         return self._func(self, X, is_train=False)[0]
#     313
#     314     def finish_update(self, optimizer: Optimizer) -> None:
#
# ~/.local/lib/python3.9/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# ~/.local/lib/python3.9/site-packages/thinc/model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~/.local/lib/python3.9/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# ~/.local/lib/python3.9/site-packages/thinc/model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~/.local/lib/python3.9/site-packages/thinc/layers/with_array.py in forward(model, Xseq, is_train)
#      28 def forward(model: Model[SeqT, SeqT], Xseq: SeqT, is_train: bool):
#      29     if isinstance(Xseq, Ragged):
# ---> 30         return _ragged_forward(
#      31             cast(Model[Ragged, Ragged], model), cast(Ragged, Xseq), is_train
#      32         )
#
# ~/.local/lib/python3.9/site-packages/thinc/layers/with_array.py in _ragged_forward(model, Xr, is_train)
#      88 ) -> Tuple[Ragged, Callable]:
#      89     layer: Model[ArrayXd, ArrayXd] = model.layers[0]
# ---> 90     Y, get_dX = layer(Xr.dataXd, is_train)
#      91
#      92     def backprop(dYr: Ragged) -> Ragged:
#
# ~/.local/lib/python3.9/site-packages/thinc/model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~/.local/lib/python3.9/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# ~/.local/lib/python3.9/site-packages/thinc/model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~/.local/lib/python3.9/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# ~/.local/lib/python3.9/site-packages/thinc/model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~/.local/lib/python3.9/site-packages/thinc/layers/maxout.py in forward(model, X, is_train)
#      47     W = model.get_param("W")
#      48     W = model.ops.reshape2f(W, nO * nP, nI)
# ---> 49     Y = model.ops.gemm(X, W, trans2=True)
#      50     Y += model.ops.reshape1f(b, nO * nP)
#      51     Z = model.ops.reshape3f(Y, Y.shape[0], nO, nP)
#
# KeyboardInterrupt:

# %%
show = nlp(docs[3].text)

# %%
import skweak
skweak.utils.display_entities(show)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Algemeen En dat kan enkel in een democratie gebeuren of ... De schaarse keren dat de
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Belgische
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  vorsten eigengereid optraden , gebeurde dat wanneer ze hun eigen positie in gevaar zagen : tijdens de koningskwestie , de onafhankelijkheid van
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kongo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  of de staatshervorming . Niet in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     België
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  en niet in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Laken
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  . pagina Hij mag geen eigen mening hebben en al zijn daden worden gedekt door de regering , die op haar beurt verantwoording verschuldigd is aan de volksvertegenwoordiging . ' Mijn koninkrijk voor paars ... ' Sommigen wijzen op de stijgende invloed van de (
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Franstalige
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  )
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     liberalen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  aan het hof .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Karl van den Broeck
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Het is een simpele oplossing , maar de legitimiteit van de machtsuitoefening is niet bijster groot . Precies daarom is de democratie ' de minst slechte staatsvorm ' : de machtsoverdracht gebeurt vreedzaam en de machthebbers hebben een legitimiteit waaraan niet te tornen valt .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Officieel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is het nochtans zeer simpel : de koning is een lege doos . Daarom is het zo'n waardevol kenmerk van een beschaafde samenleving dat de machtsoverdracht gebeurt op vreedzame wijze . In
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     België
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  was dat dan nog vaak
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     één
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  strekking binnen de meerderheid : de christen-democratische . In een monarchie wordt de vraag wie het recht heeft om de macht uit te oefenen , overgelaten aan het lot : wie geboren is uit de zaadcel van de koning , wordt later zelf koning . editie publicatie Waarnemers wijzen erop dat er sinds het aantreden van de paars-groene coalitie iets fundamenteels veranderd is in dit land . publicatiedatum Misschien is het allemaal veel simpeler . De natuurlijke bondgenoot van het hof , de
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     christelijke
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  zuil , is naar de oppositie verwezen en het land wordt bestuurd door een ' republikeinse ' coalitie . Opinie In een moderne democratie kan een koning zich alleen maar handhaven wanneer hij de meerderheid niet voor het hoofd stoot . Wie macht moet afstaan , maakt ruzie . De crypto-maçonnieke opleiding van
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     prins Laurent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  zou daar een frappant voorbeeld van zijn . De Morgen auteur Op die manier werd de koning gereduceerd tot een spreekbuis van de meerderheid .
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vrijdag
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2 juni 2000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     België
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  vroeg natuurlijk om problemen toen het in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1830
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  koos voor een ' constitutionele monarchie ' . Dat is in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Groot-Brittannië
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  zo , dat is in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nederland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  zo ( dat moest
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     koningin Beatrix
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  ondervinden ) e
